# %% [markdown]
# 0. Imports

# %%
import numpy as np
import os, glob, json
from typing import Tuple, Iterable
from multiprocessing import Pool, Process
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import time
import random
from random import shuffle
from sklearn.manifold import TSNE
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
from matplotlib import rcParamsDefault

rcParamsDefault['figure.dpi'] = 3000

# %% [markdown]
# 1. Load 10 second data (50 per class)

# %%
import matplotlib.pyplot as plt
import numpy as np

def scatter_plot_tsne(tsne_result, label_vector):
    # Get the unique labels
    unique_labels = np.unique(label_vector)

    plt.subplots(figsize=(8,6))

    # Create a color map for the labels
    colors = plt.cm.get_cmap('tab10', len(unique_labels))

    # Create a scatter plot for each label
    for i, label in enumerate(unique_labels):
        # Get the indices of the rows with this label
        indices = np.where(label_vector == label)[0]

        # Get the t-SNE coordinates for these rows
        x = tsne_result[indices, 0]
        y = tsne_result[indices, 1]

        # Plot the points with the appropriate color and label
        plt.scatter(x, y, color=colors(i), label=label)

    # Add a legend and show the plot
    plt.xlabel("Component#1 [-]")
    plt.ylabel("Component#2 [-]")

    plt.legend()
    plt.show()

def getJsonFileNamesInFolder(path2jsonFiles: str) -> Iterable[str]:
    res = glob.glob(path2jsonFiles)
    return res

def parseJsonFile(filename: str, track_dict: dict) -> dict:
    # start_t = time.perf_counter()
    file = open(filename)
    content = json.load(file)
    #print(content)

    label = content["label"]
    #print(content["label"])
    if label not in track_dict:
        track_dict[label] = 0
    
    track_dict[label] = track_dict[label] + 1
    #print("number of ", label, track_dict[label])

    file.close()
    # end_t = time.perf_counter()
    return content, track_dict

def parseJsonFiles(filenames: Iterable[str], maximumNumberOfFilesPerLabel = -1) -> dict:
    start_t = time.perf_counter()
    track_dict: dict = dict()



    results = []
    #print("parseJsonFiles", filenames)
    #print("type filenames", type(filenames))

    shuffle(filenames)
    filenames_shuffled = filenames


    #print("shuffled_filenames", filenames_shuffled)

    # with Pool() as pool:
    #     results = pool.map(parseJsonFile, filenames)
    
    for filename in filenames_shuffled:
        #print("filename", filename)
        temp,track_dict = parseJsonFile(filename, track_dict)
        
        if(maximumNumberOfFilesPerLabel == -1):
            results.append(temp)

        if(track_dict[temp["label"]] <= maximumNumberOfFilesPerLabel):
            results.append(temp)

        if(len(track_dict.keys()) == 9):
            doBreak = True
            for key in track_dict:
                if track_dict[key] < maximumNumberOfFilesPerLabel:
                    doBreak = False
            if(doBreak):
                break # break as soon as each class has reached the maximum number of datapoints

        # for filename, content, duration in results:
        #     print(f"{filename} completed in {duration:.2f}s")
    end_t = time.perf_counter()
    total_duration = end_t - start_t
    print(f"etl took {total_duration:.2f}s total")
    return results

def createXandY(path2jsonFiles: str, maximumNumberOfFilesPerLabel = -1) -> Tuple[np.ndarray, np.ndarray]:
    # (filename, dict)
    jsonFilePaths : str = getJsonFileNamesInFolder(path2jsonFiles)
    print(jsonFilePaths)
    parsedFilesList = parseJsonFiles(jsonFilePaths, maximumNumberOfFilesPerLabel=maximumNumberOfFilesPerLabel)
    
    numberOfFiles = int(len(parsedFilesList))

    

    print(type(parsedFilesList[0]))
_shape_40000_4_sampleRate_4000_durationInSeconds_10.json', '../data/evaluation/1665500894503_to_1665501015400_shape_40000_4_sampleRate_4000_durationInSeconds_10.json', '../data/evaluation/1664474664855_to_1664474785752_shape_40000_4_sampleRate_4000_durationInSeconds_10.json', '../data/evaluation/1665496538503_to_1665496659400_shape_40000_4_sampleRate_4000_durationInSeconds_10.json', '../data/evaluation/1664477568855_to_1664477689752_shape_40000_4_sampleRate ...
# etl took 8.97s total
# <class 'dict'>
# X: (405, 40000, 3) y: (405,)

# %% [markdown]
# ### Translate german labels to english

# %%
np.unique(y)
# Out:
# array(['GLT_Rollwagen', 'Gehen', 'HebenSenken', 'Hubwagen', 'Kiste liegt',
#        'Rollenbahn', 'Rolltisch', 'Sackkarre', 'vert. drehen'],
#       dtype=object)

# %%
np.unique(y_eval)
# Out:
# array(['GLT_Rollwagen', 'Gehen', 'HebenSenken', 'Hubwagen', 'Kiste liegt',
#        'Rollenbahn', 'Rolltisch', 'Sackkarre', 'vert. drehen'],
#       dtype=object)

# %%
replacementDict = {"hi": 1}

# %%
new_values = np.array(["Large load carrier trolley","Walking","Lifting and Lowering", "Pallet jack", "Idle", "Roller conveyor", "Moving table", "Sack trolley", "Rotate horizontally"])

# %%
new_values
# Out:
# array(['Large load carrier trolley', 'Walking', 'Lifting and Lowering',
#        'Pallet jack', 'Idle', 'Roller conveyor', 'Moving table',
#        'Sack trolley', 'Rotate horizontally'], dtype='<U26')

# %%
def replace_label_values(label_vector_original, new_values):
    label_vector = np.copy(label_vector_original)
    unique_values = np.unique(label_vector)
    for i in range(len(unique_values)):
        label_vector[label_vector == unique_values[i]] = new_values[i]
        print("replaced: ", unique_values[i], " with: ", new_values[i])
    return label_vector

# %%
yd = replace_label_values(y, new_values)
# Out:
# replaced:  GLT_Rollwagen  with:  Large load carrier trolley
# replaced:  Gehen  with:  Walking
# replaced:  HebenSenken  with:  Lifting and Lowering
# replaced:  Hubwagen  with:  Pallet jack
# replaced:  Kiste liegt  with:  Idle
# replaced:  Rollenbahn  with:  Roller conveyor
# replaced:  Rolltisch  with:  Moving table
# replaced:  Sackkarre  with:  Sack trolley
# replaced:  vert. drehen  with:  Rotate horizontally

# %%
y_evald = replace_label_values(y_eval, new_values)
# Out:
# replaced:  GLT_Rollwagen  with:  Large load carrier trolley
# replaced:  Gehen  with:  Walking
# replaced:  HebenSenken  with:  Lifting and Lowering
# replaced:  Hubwagen  with:  Pallet jack
# replaced:  Kiste liegt  with:  Idle
# replaced:  Rollenbahn  with:  Roller conveyor
# replaced:  Rolltisch  with:  Moving table
# replaced:  Sackkarre  with:  Sack trolley
# replaced:  vert. drehen  with:  Rotate horizontally

# %%
import pandas as pd

# %%
def create_dataframe(y, yd, y_eval, y_evald):
    df = pd.DataFrame({
        'y': y[:100],
        'yd': yd[:100],
        'y_eval': y_eval[:100],
        'y_evald': y_evald[:100]
    })
    return df

# %%
replacementTestDF = create_dataframe(y, yd, y_eval, y_evald)

# %%
replacementTestDF
# Out:
#                 y                          yd         y_eval  \
# 0       Sackkarre                Sack trolley  GLT_Rollwagen
# 1   GLT_Rollwagen  Large load carrier trolley          Gehen
# 2    vert. drehen         Rotate horizontally  GLT_Rollwagen
# 3       Sackkarre                Sack trolley      Sackkarre
# 4       Rolltisch                Moving table          Gehen
# ..            ...                         ...            ...
# 95       Hubwagen                 Pallet jack          Gehen
# 96          Gehen                     Walking      Rolltisch
# 97    Kiste liegt                        Idle    Kiste liegt
# 98      Rolltisch                Moving table      Sackkarre
# 99   vert. drehen         Rotate horizontally    Kiste liegt
#
#                        y_evald
# 0   Large load carrier trolley
# 1                      Walking
# 2   Large load carrier trolley
# 3                 Sack trolley
# 4                      Walking
# ..                         ...
# 95                     Walking
# 96                Moving table
# 97                        Idle
# 98                Sack trolley
# 99                        Idle
#
# [100 rows x 4 columns]

# %%
y = replace_label_values(y, new_values)
y_eval = replace_label_values(y_eval, new_values)
# Out:
# replaced:  GLT_Rollwagen  with:  Large load carrier trolley
# replaced:  Gehen  with:  Walking
# replaced:  HebenSenken  with:  Lifting and Lowering
# replaced:  Hubwagen  with:  Pallet jack
# replaced:  Kiste liegt  with:  Idle
# replaced:  Rollenbahn  with:  Roller conveyor
# replaced:  Rolltisch  with:  Moving table
# replaced:  Sackkarre  with:  Sack trolley
# replaced:  vert. drehen  with:  Rotate horizontally
# replaced:  GLT_Rollwagen  with:  Large load carrier trolley
# replaced:  Gehen  with:  Walking
# replaced:  HebenSenken  with:  Lifting and Lowering
# replaced:  Hubwagen  with:  Pallet jack
# replaced:  Kiste liegt  with:  Idle
# replaced:  Rollenbahn  with:  Roller conveyor
# replaced:  Rolltisch  with:  Moving table
# replaced:  Sackkarre  with:  Sack trolley
# replaced:  vert. drehen  with:  Rotate horizontally

# %% [markdown]
# 2. Remove outliers

# %%
def deleteOutliers(X, y):
    badIndices = findIllogicalValues(X, threshold=100)

    X = np.delete(X, badIndices, axis=0)
    y = np.delete(y, badIndices, axis=0)
    print("X:", X.shape, "y:", y.shape)
    return X, y
    

def findIllogicalValues(arr,threshold):    
    indices = []
    
    for idx, recording in enumerate(arr):
        flag = False
        for datapoint in recording: 
            for i, channel in enumerate(datapoint):                
                temp = channel
                if (abs(temp) > threshold):                    
                    flag = True
        if(flag):
            indices.append(idx)
    return indices

# %%
X, y = deleteOutliers(X, y)
X_eval, y_eval = deleteOutliers(X_eval, y_eval)
# Out:
# X: (1717, 40000, 3) y: (1717,)
# X: (405, 40000, 3) y: (405,)

# %% [markdown]
# 3. Apply low-pass filter

# %%
import numpy as np
from scipy import signal
def applyLowPassFilter(X):
    # set the filter parameters
    fs = 4000  # sampling frequency in Hz
    fc = 1100  # cutoff frequency in Hz
    order = 4  # filter order

    # calculate the filter coefficients
    b, a = signal.butter(order, fc / (fs / 2), 'low')

    # apply the filter to each recording of acceleration data
    filtered_accel_data = np.zeros_like(X)

    for i in range(X.shape[0]):
        filtered_accel_data[i,:,:] = signal.filtfilt(b, a, X[i,:,:], axis=0)
    print("X:", X.shape)
    return filtered_accel_data

# %%
X = applyLowPassFilter(X)
X_eval = applyLowPassFilter(X_eval)
# Out:
# X: (1717, 40000, 3)
# X: (405, 40000, 3)

# %% [markdown]
# 3.5 Tsne -Plot

# %%
X_embedded = TSNE(n_components=2, init='random', n_jobs=-1, perplexity=5).fit_transform(X[:,:,2])

# %%
X_eval_embedded = TSNE(n_components=2, init='random', n_jobs=-1, perplexity=5).fit_transform(X_eval[:,:,2])

# %%
scatter_plot_tsne(X_embedded, y)

# %%
scatter_plot_tsne(X_eval_embedded, y_eval)

# %% [markdown]
# 4. feature engineering => extract features based on the everywhereml-library's second order

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def extract_features(accel_data):
    # Initialize the result array with zeros
    num_recordings = accel_data.shape[0]
    num_axes = 3
    num_features = 20
    features = np.zeros((num_recordings, num_axes, num_features))

    # Calculate the features for each axis and recording separately
    for recording in range(num_recordings):
        recording_data = accel_data[recording]

        for axis in range(num_axes):
            axis_data = recording_data[:, axis]

            max_value = np.max(axis_data)
            min_value = np.min(axis_data)
            abs_max_value = np.max(np.abs(axis_data))
            abs_min_value = np.min(np.abs(axis_data))
            mean_value = np.mean(axis_data)
            abs_energy_value = np.sum(np.square(axis_data))
            mean_abs_change_value = np.mean(np.abs(np.diff(axis_data)))
            cid_ce_value = np.sum(np.abs(np.diff(axis_data))) / (np.sum(np.abs(axis_data)) + 1e-9)
            std_value = np.std(axis_data)
            var_value = np.var(axis_data)
            count_above_mean_value = np.sum(axis_data > mean_value)
            count_below_mean_value = np.sum(axis_data < mean_value)
            first_position_of_max_value = np.argmax(axis_data)
            first_position_of_min_value = np.argmin(axis_data)
            max_count_value = np.sum(axis_data == max_value)
            min_count_value = np.sum(axis_data == min_value)
            has_large_std_value = int(std_value > np.percentile(axis_data, 95))
            skew_value = skew(axis_data)
            kurtosis_value = kurtosis(axis_data)
            variation_coefficient_value = np.std(axis_data) / np.mean(axis_data)

            # Add the features to the result array
            features[recording, axis] = np.array([
                max_value, min_value, abs_max_value, abs_min_value, mean_value,
                abs_energy_value, mean_abs_change_value, cid_ce_value, std_value,
                var_value, count_above_mean_value, count_below_mean_value,
                first_position_of_max_value, first_position_of_min_value,
                max_count_value, min_count_value, has_large_std_value, skew_value,
                kurtosis_value, variation_coefficient_value
            ])

    # Combine the features for all three axes
    features = features.reshape(num_recordings, -1)

    # Return the features as a NumPy array
    return features

# %%
Xf = extract_features(X)
Xf_eval = extract_features(X_eval)

# %% [markdown]
# ## 4.1 TSN-E

# %%
from sklearn.manifold import TSNE

# %%
Xf_embedded = TSNE(n_components=2, init='random', n_jobs=-1, perplexity=5).fit_transform(Xf)

# %%
Xf_eval_embedded = TSNE(n_components=2, init='random', n_jobs=-1, perplexity=5).fit_transform(Xf_eval)

# %%
Xf_embedded.shape
# Out:
# (1717, 2)

# %%
y.shape
# Out:
# (1717,)

# %%
scatter_plot_tsne(Xf_embedded, y)

# %%
scatter_plot_tsne(Xf_eval_embedded, y_eval)

# %% [markdown]
# 4.5 One-Hot encoder

# %%
np.unique(y)
# Out:
# array(['Idle', 'Large load carrier trolley', 'Lifting and Lowering',
#        'Moving table', 'Pallet jack', 'Roller conveyor',
#        'Rotate horizontally', 'Sack trolley', 'Walking'], dtype=object)

# %%
np.unique(y_eval)
# Out:
# array(['Idle', 'Large load carrier trolley', 'Lifting and Lowering',
#        'Moving table', 'Pallet jack', 'Roller conveyor',
#        'Rotate horizontally', 'Sack trolley', 'Walking'], dtype=object)

# %%
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(y.reshape(-1,1))
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
enc.transform([["Rotate horizontally"]]).toarray()
# Out:
# array([[0., 0., 0., 0., 0., 0., 1., 0., 0.]])

# %%
yf=y#enc.transform(y.reshape(-1,1)).toarray()
yf_eval = y_eval#enc.transform(y_eval.reshape(-1,1)).toarray()

# %% [markdown]
# 5. Create the train-test-split (30%)

# %%
X_train, X_test, y_train, y_test = train_test_split(Xf, yf, stratify=yf, test_size=0.3, random_state=42)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (1201, 60) (516, 60)

# %% [markdown]
# 6. Train (RandomForest-) Classifier [AutoML]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import f1_score

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2

# %%
clf = RandomForestClassifier(n_estimators=20, max_depth=20, n_jobs=-1)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=20, n_jobs=-1)

# %%
clf.score(X_test, y_test)
# Out:
# 0.9941860465116279

# %%
clf.classes_
# Out:
# array(['Idle', 'Large load carrier trolley', 'Lifting and Lowering',
#        'Moving table', 'Pallet jack', 'Roller conveyor',
#        'Rotate horizontally', 'Sack trolley', 'Walking'], dtype=object)

# %%
clfx = RandomForestClassifier(n_estimators=20, max_depth=20, n_jobs=-1)
clfx.fit(Xf, yf)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=20, n_jobs=-1)

# %%
clfx.score(Xf_eval, yf_eval)
# Out:
# 0.9876543209876543

# %%
import mlflow
mlflow.set_tracking_uri("http://aiserver.tzp.haw-landshut.de:5050")

# %%
bestF1_score = -1
bestModel = None

# %%
n_jobs = -1
from mlflow.models.signature import infer_signature
mlflow.set_experiment("RandomForestClassifier_paperd")
experiment = mlflow.get_experiment_by_name("RandomForestClassifier_paper")
def run_model(n_estimators, max_depth, max_features, bestF1_score, bestModel):
    with mlflow.start_run() as run:
        max_features = max_features +1

        clfx_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, n_jobs=n_jobs, max_features=max_features)
        clfx_opt.fit(Xf, yf)
        predicted_labels = clfx_opt.predict(Xf_eval)
        
        y_true = yf_eval
        y_pred = predicted_labels

        # (rmse, mae, r2)= eval_metrics(y_true, y_pred)
        # print((rmse, mae, r2))
        f1_score_macro = f1_score(y_true, y_pred, average='macro')

        if(f1_score_macro > bestF1_score):
            bestF1_score = f1_score_macro
            bestModel = clfx

        print(n_estimators, max_depth, max_features, "f1_score_macro", f1_score_macro)
        f1_score_micro = f1_score(y_true, y_pred, average='micro')
        f1_score_weighted = f1_score(y_true, y_pred, average='weighted')
        #f1_score_average_none = f1_score(y_true, y_pred, average='None')
        mlflow.log_param("n_estimators", n_estimators)
        mlflow.log_param("max_depth", max_depth)
        mlflow.log_param("n_jobs", n_jobs)
        mlflow.log_param("max_features", max_features)
        # mlflow.log_metric("rmse", rmse)
        # mlflow.log_metric("r2", r2)
        # mlflow.log_metric("mae", mae)

        mlflow.log_metric("f1_score_macro", f1_score_macro)
        mlflow.log_metric("f1_score_micro", f1_score_micro)
        mlflow.log_metric("f1_score_weighted", f1_score_weighted)
        mlflow.log_metric("n_classes_", clfx.n_classes_)
        mlflow.log_metric("n_features_n", clfx.n_features_)
        
        #mlflow.log_metric("f1_score_average_none", f1_score_none)

        signature = infer_signature(Xf_eval, clfx.predict(Xf_eval))
        mlflow.sklearn.log_model(clfx, "randomForest",signature=signature)
        return (run.info.experiment_id, run.info.run_id, bestF1_score, bestModel)
# Out:
# 2023/04/12 17:55:31 INFO mlflow.tracking.fluent: Experiment with name 'RandomForestClassifier_paperd' does not exist. Creating a new experiment.

# %%
Xf.shape[1]
# Out:
# 60

# %%
for n_estimators in np.arange(start=1, stop=22, step=3):
    for max_depth in np.arange(start=1, stop=22, step=3):
        for max_features in np.arange(start=0, stop=Xf.shape[1], step=10):
            _, _, bestF1_score, bestModel = run_model(n_estimators=n_estimators, max_depth=max_depth, max_features=max_features, bestF1_score=bestF1_score, bestModel=bestModel)
# Out:
# 1 1 1 f1_score_macro 0.11269841269841269
# 1 1 11 f1_score_macro 0.11923113980152229
# 1 1 21 f1_score_macro 0.13464258513763463
# 1 1 31 f1_score_macro 0.12004656351554541
# 1 1 41 f1_score_macro 0.1358024691358025
# 1 1 51 f1_score_macro 0.1358024691358025
# 1 4 1 f1_score_macro 0.3332123295302608
# 1 4 11 f1_score_macro 0.4702162629873473
# 1 4 21 f1_score_macro 0.6785790197571813
# 1 4 31 f1_score_macro 0.6428149953305364
# 1 4 41 f1_score_macro 0.7928941673726153
# 1 4 51 f1_score_macro 0.47968747710654214
# 1 7 1 f1_score_macro 0.6321399215135889
# 1 7 11 f1_score_macro 0.7698665431164153
# 1 7 21 f1_score_macro 0.7329510188909458
# 1 7 31 f1_score_macro 0.8943285179240237
# 1 7 41 f1_score_macro 0.9401470572810138
# 1 7 51 f1_score_macro 0.8824268237479209
# 1 10 1 f1_score_macro 0.5358664328668481
# 1 10 11 f1_score_macro 0.9479251559154367
# 1 10 21 f1_score_macro 0.8562954617686613
# 1 10 31 f1_score_macro 0.8927922716725915
# 1 10 41 f1_score_macro 0.8856081701536246
# 1 10 51 f1_score_macro 0.8583918160421298
# 1 13 1 f1_score_macro 0.6964020698106724
# 1 13 11 f1_score_macro 0.9063364582251309
# 1 13 21 f1_score_macro 0.8906974916400375
# 1 13 31 f1_score_macro 0.9295461352292489
# 1 13 41 f1_score_macro 0.8827331488742955
# 1 13 51 f1_score_macro 0.90141561663952
# 1 16 1 f1_score_macro 0.5527684553877128
# 1 16 11 f1_score_macro 0.8246581211048416
# 1 16 21 f1_score_macro 0.8467657397260262
# 1 16 31 f1_score_macro 0.9084409306160419
# 1 16 41 f1_score_macro 0.9423411820157617
# 1 16 51 f1_score_macro 0.8980032620450543
# 1 19 1 f1_score_macro 0.7084871779372384
# 1 19 11 f1_score_macro 0.8783461858730676
# 1 19 21 f1_score_macro 0.8683224038445926
# 1 19 31 f1_score_macro 0.9425526206877114
# 1 19 41 f1_score_macro 0.8324693715258752
# 1 19 51 f1_score_macro 0.9496390518141631
# 4 1 1 f1_score_macro 0.23737723658186502
# 4 1 11 f1_score_macro 0.442167736228051
# 4 1 21 f1_score_macro 0.34632591775448923
# 4 1 31 f1_score_macro 0.27438642534419394
# 4 1 41 f1_score_macro 0.3618003859939344
# 4 1 51 f1_score_macro 0.21027979370797728
# 19 19 31 f1_score_macro 0.9751020108060691
# 19 19 41 f1_score_macro 0.9751363682726653
# 19 19 51 f1_score_macro 0.9699555968598865

# %% [markdown]
# mlflow.end_run()

# %%
bestF1_score
# Out:
# 0.9901502852813713

# %% [markdown]
# mlflow.set_tracking_uri("http://aiserver.tzp.haw-landshut.de:5050")
# mlflow.set_experiment("my-experiment-sklearn")
# signature = infer_signature(X_test, clf.predict(X_test))
# mlflow.sklearn.log_model(clf, "demo", signature=signature)

# %% [markdown]
# 7. Evaluate with test data [AutoML]

# %% [markdown]
# 8. Re-train using train- AND testdata [AutoML]

# %% [markdown]
# 9. Evaluate with evaluation data [AutoML]

# %% [markdown]
# 10. Create confusion matrix

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function plots a confusion matrix.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
# y_pred = enc.inverse_transform(clfx.predict(Xf_eval)).ravel()
# y_true = enc.inverse_transform(yf_eval).ravel()
y_pred = bestModel.predict(Xf_eval)
y_true = yf_eval

# %%
print(y_pred.shape, y_pred[0])
print(y_true.shape[0], y_true[0])
# Out:
# (405,) Idle
# 405 Idle

# %%
cm=confusion_matrix(y_true, y_pred, labels=np.unique(y))

# %%
plot_confusion_matrix(cm,classes = np.unique(y),normalize=False)
plt.show()
# Out:
# Confusion matrix, without normalization

# %%
import pandas as pd

# %%
df = pd.DataFrame({'True Label': y_true, 'Predicted Label': y_pred})

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df)
# Out:
#                      True Label             Predicted Label
# 0                          Idle                        Idle
# 1                  Sack trolley                Sack trolley
# 2          Lifting and Lowering        Lifting and Lowering
# 3                          Idle                        Idle
# 4                  Moving table                Moving table
# 5                          Idle                        Idle
# 6                  Sack trolley                Sack trolley
# 7          Lifting and Lowering        Lifting and Lowering
# 8                          Idle                        Idle
# 9                  Moving table                Moving table
# 10                      Walking                     Walking
# 11   Large load carrier trolley  Large load carrier trolley
# 12         Lifting and Lowering        Lifting and Lowering
# 13                      Walking                     Walking
# 14              Roller conveyor             Roller conveyor
# 15                      Walking                     Walking
# 16   Large load carrier trolley  Large load carrier trolley
# 17   Large load carrier trolley  Large load carrier trolley
# 18         Lifting and Lowering        Lifting and Lowering
# 19          Rotate horizontally         Rotate horizontally
# 20          Rotate horizontally         Rotate horizontally
# 21   Large load carrier trolley  Large load carrier trolley
# 22         Lifting and Lowering        Lifting and Lowering
# 23         Lifting and Lowering        Lifting and Lowering
# 24   Large load carrier trolley  Large load carrier trolley
# 25          Rotate horizontally         Rotate horizontally
# 26                         Idle                        Idle
# 27                 Moving table                Moving table
# 28                      Walking                     Walking
# 29   Large load carrier trolley  Large load carrier trolley
# 30                 Moving table                Moving table
# 31         Lifting and Lowering        Lifting and Lowering
# 32                 Moving table                Moving table
# 33                      Walking                     Walking
# 34                 Sack trolley                Sack trolley
# 35                  Pallet jack                 Pallet jack
# 36              Roller conveyor             Roller conveyor
# 37              Roller conveyor             Roller conveyor
# 38                      Walking                     Walking
# 39                 Moving table                Moving table
# 40                         Idle                        Idle
# 41         Lifting and Lowering        Lifting and Lowering
# 42                 Moving table                Moving table
# 43                         Idle                        Idle
# 44                  Pallet jack                 Pallet jack
# 45                  Pallet jack                 Pallet jack
# 46   Large load carrier trolley  Large load carrier trolley
# 47                      Walking                     Walking
# 48                 Sack trolley                Sack trolley
# 49   Large load carrier trolley  Large load carrier trolley
# 50                         Idle                        Idle
# 51                 Sack trolley                Sack trolley
# 52   Large load carrier trolley  Large load carrier trolley
# 53                 Sack trolley                Sack trolley
# 54         Lifting and Lowering        Lifting and Lowering
# 55         Lifting and Lowering                     Walking
# 56                 Sack trolley                Sack trolley
# 57              Roller conveyor             Roller conveyor
# 58              Roller conveyor             Roller conveyor
# 59   Large load carrier trolley  Large load carrier trolley
# 60                 Moving table                Moving table
# 61                         Idle                        Idle
# 62                         Idle                        Idle
# 63         Lifting and Lowering        Lifting and Lowering
# 64                         Idle                        Idle
# 65                      Walking                     Walking
# 66              Roller conveyor             Roller conveyor
# 67         Lifting and Lowering        Lifting and Lowering
# 68                  Pallet jack                 Pallet jack
# 69   Large load carrier trolley  Large load carrier trolley
# 70                 Moving table                Moving table
# 71          Rotate horizontally         Rotate horizontally
# 72                         Idle                        Idle
# 73              Roller conveyor             Roller conveyor
# 74                 Sack trolley                Sack trolley
# 75   Large load carrier trolley  Large load carrier trolley
# 76                 Moving table                 Pallet jack
# 77                 Moving table                Moving table
# 78                         Idle                        Idle
# 79                  Pallet jack                 Pallet jack
# 80                 Moving table                Moving table
# 81                  Pallet jack                 Pallet jack
# 82                 Sack trolley                Sack trolley
# 83                  Pallet jack                 Pallet jack
# 84   Large load carrier trolley  Large load carrier trolley
# 85                 Sack trolley                Sack trolley
# 86                 Sack trolley                Sack trolley
# 87                      Walking                     Walking
# 88                      Walking                     Walking
# 89          Rotate horizontally         Rotate horizontally
# 90                         Idle                        Idle
# 91                 Sack trolley                Sack trolley
# 92                  Pallet jack                 Pallet jack
# 93                 Moving table                Moving table
# 94                      Walking                     Walking
# 95         Lifting and Lowering        Lifting and Lowering
# 96                  Pallet jack                 Pallet jack
# 97         Lifting and Lowering        Lifting and Lowering
# 98              Roller conveyor             Roller conveyor
# 99                 Sack trolley                Sack trolley
# 100                     Walking                     Walking
# 101         Rotate horizontally         Rotate horizontally
# 102         Rotate horizontally         Rotate horizontally
# 103         Rotate horizontally         Rotate horizontally
# 104                Moving table                Moving table
# 105                        Idle                        Idle
# 106                        Idle                        Idle
# 107                 Pallet jack                 Pallet jack
# 108                Sack trolley                Sack trolley
# 109        Lifting and Lowering        Lifting and Lowering
# 110                        Idle                        Idle
# 111        Lifting and Lowering        Lifting and Lowering
# 112         Rotate horizontally         Rotate horizontally
# 113                Moving table                Moving table
# 114                 Pallet jack                 Pallet jack
# 115                        Idle                        Idle
# 116  Large load carrier trolley  Large load carrier trolley
# 117                Moving table                Moving table
# 118                 Pallet jack                 Pallet jack
# 119                Sack trolley                Sack trolley
# 120         Rotate horizontally         Rotate horizontally
# 121                 Pallet jack                Moving table
# 122                Sack trolley                Sack trolley
# 123                Sack trolley                Sack trolley
# 124                Sack trolley                Sack trolley
# 125                Moving table                Moving table
# 126                Moving table                Moving table
# 127                        Idle                        Idle
# 128         Rotate horizontally         Rotate horizontally
# 129        Lifting and Lowering        Lifting and Lowering
# 130        Lifting and Lowering        Lifting and Lowering
# 131                 Pallet jack                 Pallet jack
# 132         Rotate horizontally         Rotate horizontally
# 133                        Idle                        Idle
# 134                        Idle                        Idle
# 135                Moving table                Moving table
# 136                     Walking                     Walking
# 137         Rotate horizontally         Rotate horizontally
# 138                Sack trolley                Sack trolley
# 139         Rotate horizontally         Rotate horizontally
# 140  Large load carrier trolley  Large load carrier trolley
# 141                 Pallet jack                 Pallet jack
# 142  Large load carrier trolley  Large load carrier trolley
# 143                Moving table                Moving table
# 144                 Pallet jack                 Pallet jack
# 145        Lifting and Lowering        Lifting and Lowering
# 146             Roller conveyor             Roller conveyor
# 147                 Pallet jack                 Pallet jack
# 148                        Idle                        Idle
# 149                        Idle                        Idle
# 150                        Idle                        Idle
# 151             Roller conveyor             Roller conveyor
# 152         Rotate horizontally         Rotate horizontally
# 153                Sack trolley                Sack trolley
# 154                     Walking                     Walking
# 155             Roller conveyor             Roller conveyor
# 156        Lifting and Lowering        Lifting and Lowering
# 157                Moving table                Moving table
# 158                Sack trolley                Sack trolley
# 159                     Walking                     Walking
# 160                     Walking                     Walking
# 161        Lifting and Lowering        Lifting and Lowering
# 162                Sack trolley                Sack trolley
# 163                     Walking                     Walking
# 164                     Walking                     Walking
# 165                Sack trolley                Sack trolley
# 166                Sack trolley                Sack trolley
# 167                     Walking                     Walking
# 168                Moving table                Moving table
# 169                     Walking                     Walking
# 170         Rotate horizontally         Rotate horizontally
# 171             Roller conveyor             Roller conveyor
# 172        Lifting and Lowering                     Walking
# 173             Roller conveyor             Roller conveyor
# 174                Moving table                Moving table
# 175                     Walking                     Walking
# 176                     Walking                     Walking
# 177                     Walking                     Walking
# 178                 Pallet jack                 Pallet jack
# 179                        Idle                        Idle
# 180             Roller conveyor             Roller conveyor
# 181  Large load carrier trolley  Large load carrier trolley
# 182        Lifting and Lowering        Lifting and Lowering
# 183             Roller conveyor             Roller conveyor
# 184                Moving table                Moving table
# 185  Large load carrier trolley  Large load carrier trolley
# 186             Roller conveyor             Roller conveyor
# 187                     Walking                     Walking
# 188                 Pallet jack                 Pallet jack
# 189         Rotate horizontally         Rotate horizontally
# 190         Rotate horizontally  Large load carrier trolley
# 191                 Pallet jack                 Pallet jack
# 192                     Walking                     Walking
# 193        Lifting and Lowering        Lifting and Lowering
# 194                        Idle                        Idle
# 195                Moving table                Moving table
# 196             Roller conveyor                Moving table
# 197                Sack trolley                Sack trolley
# 198                     Walking                     Walking
# 199             Roller conveyor             Roller conveyor
# 200                Sack trolley                Sack trolley
# 201             Roller conveyor             Roller conveyor
# 202         Rotate horizontally         Rotate horizontally
# 203  Large load carrier trolley  Large load carrier trolley
# 204                     Walking                     Walking
# 205             Roller conveyor             Roller conveyor
# 206         Rotate horizontally         Rotate horizontally
# 207         Rotate horizontally         Rotate horizontally
# 208                Sack trolley                Sack trolley
# 209                        Idle                        Idle
# 210             Roller conveyor             Roller conveyor
# 211                Sack trolley                Sack trolley
# 212                 Pallet jack                 Pallet jack
# 213                        Idle                        Idle
# 214             Roller conveyor             Roller conveyor
# 215                Moving table                Moving table
# 216                Moving table                Moving table
# 217  Large load carrier trolley  Large load carrier trolley
# 218                Moving table                Moving table
# 219                 Pallet jack                 Pallet jack
# 220                     Walking                     Walking
# 221        Lifting and Lowering        Lifting and Lowering
# 222             Roller conveyor             Roller conveyor
# 223                 Pallet jack                Moving table
# 224         Rotate horizontally         Rotate horizontally
# 225                        Idle                        Idle
# 226  Large load carrier trolley  Large load carrier trolley
# 227  Large load carrier trolley  Large load carrier trolley
# 228         Rotate horizontally         Rotate horizontally
# 229                 Pallet jack                 Pallet jack
# 230             Roller conveyor             Roller conveyor
# 231        Lifting and Lowering        Lifting and Lowering
# 232                Sack trolley                Sack trolley
# 233         Rotate horizontally         Rotate horizontally
# 234             Roller conveyor             Roller conveyor
# 235                 Pallet jack                 Pallet jack
# 236        Lifting and Lowering        Lifting and Lowering
# 237                Sack trolley                Sack trolley
# 238             Roller conveyor             Roller conveyor
# 239        Lifting and Lowering        Lifting and Lowering
# 240                Moving table                Moving table
# 241                Sack trolley                Sack trolley
# 242                Sack trolley                Sack trolley
# 243             Roller conveyor             Roller conveyor
# 244                 Pallet jack                 Pallet jack
# 245                Sack trolley                Sack trolley
# 246             Roller conveyor                Moving table
# 247                 Pallet jack                 Pallet jack
# 248         Rotate horizontally         Rotate horizontally
# 249                 Pallet jack                 Pallet jack
# 250  Large load carrier trolley  Large load carrier trolley
# 251                Moving table                Moving table
# 252                     Walking                     Walking
# 253         Rotate horizontally         Rotate horizontally
# 254             Roller conveyor             Roller conveyor
# 255                     Walking                     Walking
# 256         Rotate horizontally         Rotate horizontally
# 257                Moving table                Moving table
# 258             Roller conveyor             Roller conveyor
# 259                Moving table                Moving table
# 260             Roller conveyor             Roller conveyor
# 261                        Idle                        Idle
# 262        Lifting and Lowering        Lifting and Lowering
# 263  Large load carrier trolley  Large load carrier trolley
# 264                 Pallet jack                 Pallet jack
# 265             Roller conveyor             Roller conveyor
# 266         Rotate horizontally         Rotate horizontally
# 267                 Pallet jack                 Pallet jack
# 268  Large load carrier trolley  Large load carrier trolley
# 269                        Idle                        Idle
# 270                Sack trolley                Sack trolley
# 271             Roller conveyor             Roller conveyor
# 272                        Idle                        Idle
# 273                Moving table                Moving table
# 274        Lifting and Lowering        Lifting and Lowering
# 275        Lifting and Lowering        Lifting and Lowering
# 276        Lifting and Lowering        Lifting and Lowering
# 277                Sack trolley                Sack trolley
# 278             Roller conveyor             Roller conveyor
# 279        Lifting and Lowering        Lifting and Lowering
# 280                        Idle                        Idle
# 281             Roller conveyor             Roller conveyor
# 282  Large load carrier trolley  Large load carrier trolley
# 283  Large load carrier trolley  Large load carrier trolley
# 284                Moving table                Moving table
# 285                     Walking                     Walking
# 286             Roller conveyor             Roller conveyor
# 287        Lifting and Lowering        Lifting and Lowering
# 288         Rotate horizontally         Rotate horizontally
# 289  Large load carrier trolley  Large load carrier trolley
# 290  Large load carrier trolley  Large load carrier trolley
# 291                 Pallet jack                 Pallet jack
# 292        Lifting and Lowering        Lifting and Lowering
# 293        Lifting and Lowering        Lifting and Lowering
# 294                     Walking                     Walking
# 295             Roller conveyor             Roller conveyor
# 296  Large load carrier trolley  Large load carrier trolley
# 297                Moving table                Moving table
# 298         Rotate horizontally         Rotate horizontally
# 299        Lifting and Lowering        Lifting and Lowering
# 300                     Walking                     Walking
# 301                     Walking                     Walking
# 302                        Idle                        Idle
# 303                     Walking                     Walking
# 304                Sack trolley                Sack trolley
# 305                Moving table                Moving table
# 306                     Walking                     Walking
# 307  Large load carrier trolley  Large load carrier trolley
# 308  Large load carrier trolley  Large load carrier trolley
# 309                 Pallet jack                 Pallet jack
# 310         Rotate horizontally         Rotate horizontally
# 311                Moving table                Moving table
# 312                Sack trolley                Sack trolley
# 313                 Pallet jack                 Pallet jack
# 314  Large load carrier trolley  Large load carrier trolley
# 315  Large load carrier trolley  Large load carrier trolley
# 316                 Pallet jack                 Pallet jack
# 317         Rotate horizontally         Rotate horizontally
# 318                        Idle                        Idle
# 319         Rotate horizontally         Rotate horizontally
# 320  Large load carrier trolley  Large load carrier trolley
# 321                     Walking                     Walking
# 322                Sack trolley                Sack trolley
# 323        Lifting and Lowering        Lifting and Lowering
# 324                 Pallet jack                 Pallet jack
# 325        Lifting and Lowering        Lifting and Lowering
# 326         Rotate horizontally         Rotate horizontally
# 327                Sack trolley                Sack trolley
# 328                 Pallet jack                 Pallet jack
# 329                Moving table                Moving table
# 330                Sack trolley                Sack trolley
# 331                     Walking                     Walking
# 332                     Walking                     Walking
# 333  Large load carrier trolley  Large load carrier trolley
# 334                        Idle                        Idle
# 335        Lifting and Lowering        Lifting and Lowering
# 336                Moving table                Moving table
# 337         Rotate horizontally         Rotate horizontally
# 338                 Pallet jack                 Pallet jack
# 339        Lifting and Lowering        Lifting and Lowering
# 340         Rotate horizontally         Rotate horizontally
# 341                        Idle                        Idle
# 342                Sack trolley                Sack trolley
# 343  Large load carrier trolley  Large load carrier trolley
# 344         Rotate horizontally         Rotate horizontally
# 345             Roller conveyor             Roller conveyor
# 346             Roller conveyor             Roller conveyor
# 347         Rotate horizontally         Rotate horizontally
# 348                        Idle                        Idle
# 349         Rotate horizontally         Rotate horizontally
# 350                     Walking                     Walking
# 351  Large load carrier trolley  Large load carrier trolley
# 352  Large load carrier trolley  Large load carrier trolley
# 353                 Pallet jack                 Pallet jack
# 354                     Walking                     Walking
# 355  Large load carrier trolley  Large load carrier trolley
# 356                Moving table                Moving table
# 357                 Pallet jack                 Pallet jack
# 358                        Idle                        Idle
# 359                     Walking                     Walking
# 360         Rotate horizontally         Rotate horizontally
# 361                        Idle                        Idle
# 362             Roller conveyor             Roller conveyor
# 363                Moving table                Moving table
# 364                        Idle                        Idle
# 365                        Idle                        Idle
# 366                 Pallet jack                 Pallet jack
# 367             Roller conveyor             Roller conveyor
# 368                Sack trolley                Sack trolley
# 369  Large load carrier trolley  Large load carrier trolley
# 370                Moving table                Moving table
# 371                        Idle                        Idle
# 372                        Idle                        Idle
# 373                     Walking                     Walking
# 374  Large load carrier trolley  Large load carrier trolley
# 375                Sack trolley                Sack trolley
# 376        Lifting and Lowering        Lifting and Lowering
# 377                Moving table                Moving table
# 378         Rotate horizontally         Rotate horizontally
# 379                Moving table                Moving table
# 380             Roller conveyor             Roller conveyor
# 381         Rotate horizontally         Rotate horizontally
# 382  Large load carrier trolley  Large load carrier trolley
# 383         Rotate horizontally         Rotate horizontally
# 384                 Pallet jack                 Pallet jack
# 385                Sack trolley                Sack trolley
# 386             Roller conveyor             Roller conveyor
# 387        Lifting and Lowering        Lifting and Lowering
# 388        Lifting and Lowering        Lifting and Lowering
# 389                        Idle                        Idle
# 390  Large load carrier trolley  Large load carrier trolley
# 391                 Pallet jack                 Pallet jack
# 392  Large load carrier trolley  Large load carrier trolley
# 393                 Pallet jack                 Pallet jack
# 394                Moving table                Moving table
# 395                     Walking        Lifting and Lowering
# 396        Lifting and Lowering        Lifting and Lowering
# 397         Rotate horizontally         Rotate horizontally
# 398             Roller conveyor             Roller conveyor
# 399                 Pallet jack                 Pallet jack
# 400                Sack trolley                Sack trolley
# 401                     Walking                     Walking
# 402                 Pallet jack                 Pallet jack
# 403         Rotate horizontally         Rotate horizontally
# 404             Roller conveyor             Roller conveyor

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np

def plot_classification_report(y_true, y_pred, target_names=None, figsize=(8, 6)):
    """
    Generate a classification report and plot it using matplotlib.
    
    Parameters
    ----------
    y_true : array-like
        Ground truth (correct) target values.
    y_pred : array-like
        Estimated targets as returned by a classifier.
    target_names : list of str, default=None
        List of labels to index the report. If None, target_names will be set to the unique values in y_true.
    figsize : tuple of float, default=(8, 6)
        Figure size in inches in the form (width, height).
    """
    report = classification_report(y_true, y_pred, target_names=target_names, output_dict=True)
    fig, ax = plt.subplots(figsize=figsize)
    columns = ['precision', 'recall', 'f1-score', 'support']
    rows = target_names if target_names else list(report.keys())[:-1]
    cell_text = []
    for row in rows:
        cell_text.append([f"{report[row][column]:.3f}" if isinstance(report[row][column], float) else report[row][column] for column in columns])


    ax.axis('off')
    ax.table(cellText=cell_text,
             rowLabels=rows,
             colLabels=columns,
             loc='center')
    ax.set_title("Classification Report")
    plt.show()

# %%
np.unique(y)
# Out:
# array(['Idle', 'Large load carrier trolley', 'Lifting and Lowering',
#        'Moving table', 'Pallet jack', 'Roller conveyor',
#        'Rotate horizontally', 'Sack trolley', 'Walking'], dtype=object)

# %%
new_values.tolist()
# Out:
# ['Large load carrier trolley',
#  'Walking',
#  'Lifting and Lowering',
#  'Pallet jack',
#  'Idle',
#  'Roller conveyor',
#  'Moving table',
#  'Sack trolley',
#  'Rotate horizontally']

# %%
plot_classification_report(y_true, y_pred, target_names=new_values.tolist())

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
np.unique(y).astype('<U20')[0]
# Out:
# 'Idle'

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ```bash
# !mlflow ui
# ```
